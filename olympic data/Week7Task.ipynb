# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('seaborn-white')
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df=pd.read_csv("/content/drive/MyDrive/Medals_task.csv")
df.head()
# Out:
#                      Team/NOC  Gold  Silver  Bronze  Total
# 0    United States of America    39      41      33    113
# 1  People's Republic of China    38      32      18     88
# 2                       Japan    27      14      17     58
# 3               Great Britain    22      21      22     65
# 4                         ROC    20      28      23     71

# %%
import matplotlib.pyplot as plt
import numpy as np
# Fixing random state for reproducibility
np.random.seed(19680801)
N = 100
r0 = 0.6
x = 0.9 * np.random.rand(N)
y = 0.9 * np.random.rand(N)
area = (20 * np.random.rand(N))**2  # 0 to 10 point radii
c = np.sqrt(area)
r = np.sqrt(x * x + y * y)
area1 = np.ma.masked_where(r < r0, area)
area2 = np.ma.masked_where(r >= r0, area)
plt.scatter(x, y, s=area1, marker='^', c=c)
plt.scatter(x, y, s=area2, marker='o', c=c)
# Show the boundary between the regions:
theta = np.arange(0, np.pi / 2, 0.01)
plt.plot(r0 * np.cos(theta), r0 * np.sin(theta))
plt.show()

# %%
x = df['Team/NOC']
y1 = df['Gold']
y2 = df['Silver']
y3 = df['Bronze']

# Plot
plt.rcParams.update({'figure.figsize':(10,8), 'figure.dpi':100})
plt.scatter(x,y1,color='blue', marker= '*', label='Gold Medals')
plt.scatter(x,y2,color= 'red', marker='v', label='Silver Medals')
plt.scatter(x,y3,color= 'green', marker='.', label='Bronze Medals')


# Decorate
plt.title('Distributions: Color and Shape change')
plt.xlabel('X - value')
plt.ylabel('Y - value')
plt.legend(loc='best')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
# Fixing random state for reproducibility
np.random.seed(19680801)
N = 100
r0 = 70
x = df['Gold']
y = df['Bronze']
area = (20 * np.random.rand(N))**2  # 0 to 10 point radii
c = np.sqrt(area)
r = np.sqrt(x * x + y * y)
area1 = np.ma.masked_where(r < 100, area)
area2 = np.ma.masked_where(r >= 100, area)
plt.scatter(x, y, s=area1, marker='^', c=c)
plt.scatter(x, y, s=area2, marker='o', c=c)
# Show the boundary between the regions:
theta = np.arange(0, np.pi / 2, 0.01)
plt.plot(r0 * np.cos(theta), r0 * np.sin(theta))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-4-e4fb6d29f2c7> in <module>()
#      10 c = np.sqrt(area)
#      11 r = np.sqrt(x * x + y * y)
# ---> 12 area1 = np.ma.masked_where(r < 100, area)
#      13 area2 = np.ma.masked_where(r >= 100, area)
#      14 plt.scatter(x, y, s=area1, marker='^', c=c)
#
# /usr/local/lib/python3.7/dist-packages/numpy/ma/core.py in masked_where(condition, a, copy)
#    1928     if cshape and cshape != ashape:
#    1929         raise IndexError("Inconsistent shape between the condition and the input"
# -> 1930                          " (got %s and %s)" % (cshape, ashape))
#    1931     if hasattr(a, '_mask'):
#    1932         cond = mask_or(cond, a._mask)
#
# IndexError: Inconsistent shape between the condition and the input (got (34,) and (100,))

# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.colors
import pandas as pd
d1 = pd.read_csv("/content/drive/MyDrive/Medals.csv")
a = np.linspace(-10, 10)
A = d1['Gold']
B = d1['Silver']
A, B = np.meshgrid(a, a)
X = np.sqrt((A * 2 + B * 2))
figure, (axes1, axes2) = plt.subplots(ncols=2)
plt.title("Rainbow Contour Plot")
colors = ["violet","indigo","blue","green","yellow","orange","red"]
contour = axes1.contourf(A, B, X, colors=colors)
cmap = matplotlib.colors.ListedColormap(colors)
contour = axes2.contourf(A, B, X, cmap=cmap)
figure.colorbar(contour)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:10: RuntimeWarning: invalid value encountered in sqrt
#   # Remove the CWD from sys.path while we load stuff.
